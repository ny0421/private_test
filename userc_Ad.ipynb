# %%
import os
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from pathlib import Path
from collections import OrderedDict
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn import preprocessing
import matplotlib.pyplot as plt
import pytorch_lightning as pl
from pytorch_lightning.loggers import WandbLogger
import wandb

# %%
datafile_path = Path('C:/Users/Ni Ying/Desktop/data/usercerter.xlsx')
datasets_root = Path('C:/Users/Ni Ying/Desktop/data/working')
data = pd.read_excel(datafile_path)

# %%
data.head()
# Out:
#    uid type    nickname level ident  score          intro  ifintro  intro_len  \
# 0    1  pri  admin_wdzj    V9   投资人  15114  这家伙很懒什么都没有留下!        0         13
# 1   12  pri      P2PGTR    V7   投资人   4667  这家伙很懒什么都没有留下!        0         13
# 2   18  pri       论坛管理员    V9   投资人  59969  这家伙很懒什么都没有留下!        0         13
# 3   22  pri      cjtd88    V8   投资人   9738  这家伙很懒什么都没有留下!        0         13
# 4   35  pri     ZSQ6666    V6   投资人   1190  这家伙很懒什么都没有留下!        0         13
#
#    touy  fans  author  shouc
# 0    16    55       0  10009
# 1     3    13       0      0
# 2   161   172       0      0
# 3     0     7       0      0
# 4     0     6       0      0
